# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Read the data set

# %%
data_1=pd.read_csv(r"C:\Users\Reyuvel K Kunjumon\OneDrive\Desktop\StockProphet\1.1\BAJFINANCE.csv")

# %%
data_1.head()
# Out:
#          Date      Symbol Series  Prev Close   Open   High   Low   Last  \
# 0  2000-01-03  BAJAUTOFIN     EQ       46.95  49.45  50.75  46.5  50.75
# 1  2000-01-04  BAJAUTOFIN     EQ       50.75  53.20  53.20  47.9  48.00
# 2  2000-01-05  BAJAUTOFIN     EQ       48.10  46.55  47.40  44.6  44.60
# 3  2000-01-06  BAJAUTOFIN     EQ       44.60  43.50  46.00  42.1  46.00
# 4  2000-01-07  BAJAUTOFIN     EQ       45.25  48.00  48.00  42.0  42.90
#
#    Close   VWAP  Volume      Turnover  Trades  Deliverable Volume  %Deliverble
# 0  50.75  50.05    7600  3.803800e+10     NaN                 NaN          NaN
# 1  48.10  48.56    5000  2.428000e+10     NaN                 NaN          NaN
# 2  44.60  45.47    3500  1.591450e+10     NaN                 NaN          NaN
# 3  45.25  44.43    6200  2.754750e+10     NaN                 NaN          NaN
# 4  42.90  44.44    3500  1.555550e+10     NaN                 NaN          NaN

# %% [markdown]
# to find number of rows and columns for just an overview of data use shape().it returns (no:rows, no"column)

# %%
data_1.shape
# Out:
# (5070, 15)

# %% [markdown]
# ## this is time series data.So let"s make date as the index of the data

# %%
data_1.set_index('Date',inplace=True)

# %% [markdown]
# # to check what is the trend of the volume weight average price

# %%
data_1['VWAP'].plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## check for any missing values

# %%
data_1.isna().sum()
# Out:
# Symbol                   0
# Series                   0
# Prev Close               0
# Open                     0
# High                     0
# Low                      0
# Last                     0
# Close                    0
# VWAP                     0
# Volume                   0
# Turnover                 0
# Trades                2779
# Deliverable Volume     446
# %Deliverble            446
# dtype: int64

# %% [markdown]
# from the above data et it is clear that the columns trades,deliverable volume, %Deliverable have missing values.The rule is to delete the null values if the %of missing values is less 5.

# %% [markdown]
# ## if you want to check the % of null data,see below

# %%
no_rows=data_1.shape[0]
no_null_of_deliverable=data_1['%Deliverble'].isnull().sum()
percent_of_deliverable_missing_value=(no_null_of_deliverable/no_rows)*100
percent_of_deliverable_missing_value
# Out:
# 8.796844181459566

# %% [markdown]
# and now for our convenience we will delete all the missing value rows

# %%
data_1.dropna(inplace=True)
data_1.isna().sum()
# Out:
# Symbol                0
# Series                0
# Prev Close            0
# Open                  0
# High                  0
# Low                   0
# Last                  0
# Close                 0
# VWAP                  0
# Volume                0
# Turnover              0
# Trades                0
# Deliverable Volume    0
# %Deliverble           0
# dtype: int64

# %% [markdown]
# all the missing value rows are deleted

# %%
data_1.shape
# Out:
# (2291, 14)

# %%
data_2=data_1

# %% [markdown]
# ### Feature Engineering Works

# %%
data_2.dtypes #to see the datatypes
# Out:
# Symbol                 object
# Series                 object
# Prev Close            float64
# Open                  float64
# High                  float64
# Low                   float64
# Last                  float64
# Close                 float64
# VWAP                  float64
# Volume                  int64
# Turnover              float64
# Trades                float64
# Deliverable Volume    float64
# %Deliverble           float64
# dtype: object

# %%
data_2.columns # to ee the kist of columns
# Out:
# Index(['Symbol', 'Series', 'Prev Close', 'Open', 'High', 'Low', 'Last',
#        'Close', 'VWAP', 'Volume', 'Turnover', 'Trades', 'Deliverable Volume',
#        '%Deliverble'],
#       dtype='object')

# %% [markdown]
# ### next we are gonna makew use of rolling sum to get a good insight on the data

# %%
lag_features = ['High','Low','Last','Turnover','Trades']
window1=3
window2=7

# %%
# iterate through all the above mentioned columns to find rolling mean with two type of rolling windows 3 and 7
for feature in lag_features:
    data_2[feature + 'rolling_mean_3']=data_2[feature].rolling(window1).mean()
    data_2[feature + 'rolling_mean_7']=data_2[feature].rolling(window2).mean()

# %%
# iterate through all the above mentioned columns to find rolling std deviation with two types of rolling windows 3 and 7
for feature in lag_features:
    data_2[feature + 'rolling_std_3']=data_2[feature].rolling(window1).std()
    data_2[feature + 'rolling_std_7']=data_2[feature].rolling(window2).std()

# %%
data_2.columns
# Out:
# Index(['Symbol', 'Series', 'Prev Close', 'Open', 'High', 'Low', 'Last',
#        'Close', 'VWAP', 'Volume', 'Turnover', 'Trades', 'Deliverable Volume',
#        '%Deliverble', 'Highrolling_mean_3', 'Highrolling_mean_7',
#        'Lowrolling_mean_3', 'Lowrolling_mean_7', 'Lastrolling_mean_3',
#        'Lastrolling_mean_7', 'Turnoverrolling_mean_3',
#        'Turnoverrolling_mean_7', 'Tradesrolling_mean_3',
#        'Tradesrolling_mean_7', 'Highrolling_std_3', 'Highrolling_std_7',
#        'Lowrolling_std_3', 'Lowrolling_std_7', 'Lastrolling_std_3',
#        'Lastrolling_std_7', 'Turnoverrolling_std_3', 'Turnoverrolling_std_7',
#        'Tradesrolling_std_3', 'Tradesrolling_std_7'],
#       dtype='object')

# %%
data_2.head()
# Out:
#                 Symbol Series  Prev Close    Open    High     Low    Last  \
# Date
# 2011-06-01  BAJFINANCE     EQ      616.70  617.00  636.50  616.00  627.00
# 2011-06-02  BAJFINANCE     EQ      631.85  625.00  638.90  620.00  634.00
# 2011-06-03  BAJFINANCE     EQ      633.45  625.15  637.80  620.00  623.00
# 2011-06-06  BAJFINANCE     EQ      625.00  620.00  641.00  611.35  611.35
# 2011-06-07  BAJFINANCE     EQ      614.00  604.00  623.95  604.00  619.90
#
#              Close    VWAP  Volume  ...  Highrolling_std_3  Highrolling_std_7  \
# Date                                ...
# 2011-06-01  631.85  627.01    6894  ...                NaN                NaN
# 2011-06-02  633.45  636.04    2769  ...                NaN                NaN
# 2011-06-03  625.00  625.09   51427  ...           1.201388                NaN
# 2011-06-06  614.00  616.03    5446  ...           1.625833                NaN
# 2011-06-07  619.15  617.73    5991  ...           9.062422                NaN
#
#             Lowrolling_std_3  Lowrolling_std_7  Lastrolling_std_3  \
# Date
# 2011-06-01               NaN               NaN                NaN
# 2011-06-02               NaN               NaN                NaN
# 2011-06-03          2.309401               NaN           5.567764
# 2011-06-06          4.994080               NaN          11.326554
# 2011-06-07          8.008797               NaN           6.033725
#
#             Lastrolling_std_7  Turnoverrolling_std_3  Turnoverrolling_std_7  \
# Date
# 2011-06-01                NaN                    NaN                    NaN
# 2011-06-02                NaN                    NaN                    NaN
# 2011-06-03                NaN           1.685217e+12                    NaN
# 2011-06-06                NaN           1.710136e+12                    NaN
# 2011-06-07                NaN           1.652377e+12                    NaN
#
#             Tradesrolling_std_3  Tradesrolling_std_7
# Date
# 2011-06-01                  NaN                  NaN
# 2011-06-02                  NaN                  NaN
# 2011-06-03           670.500559                  NaN
# 2011-06-06           148.769396                  NaN
# 2011-06-07            78.270897                  NaN
#
# [5 rows x 34 columns]

# %%
data_2.shape
# Out:
# (2291, 34)

# %% [markdown]
# ### here null values came.delete those null values

# %%
data_2.isna().sum()
# Out:
# Symbol                    0
# Series                    0
# Prev Close                0
# Open                      0
# High                      0
# Low                       0
# Last                      0
# Close                     0
# VWAP                      0
# Volume                    0
# Turnover                  0
# Trades                    0
# Deliverable Volume        0
# %Deliverble               0
# Highrolling_mean_3        2
# Highrolling_mean_7        6
# Lowrolling_mean_3         2
# Lowrolling_mean_7         6
# Lastrolling_mean_3        2
# Lastrolling_mean_7        6
# Turnoverrolling_mean_3    2
# Turnoverrolling_mean_7    6
# Tradesrolling_mean_3      2
# Tradesrolling_mean_7      6
# Highrolling_std_3         2
# Highrolling_std_7         6
# Lowrolling_std_3          2
# Lowrolling_std_7          6
# Lastrolling_std_3         2
# Lastrolling_std_7         6
# Turnoverrolling_std_3     2
# Turnoverrolling_std_7     6
# Tradesrolling_std_3       2
# Tradesrolling_std_7       6
# dtype: int64

# %%
data_2.dropna(inplace=True)

# %%
data_2.isna().sum()
# Out:
# Symbol                    0
# Series                    0
# Prev Close                0
# Open                      0
# High                      0
# Low                       0
# Last                      0
# Close                     0
# VWAP                      0
# Volume                    0
# Turnover                  0
# Trades                    0
# Deliverable Volume        0
# %Deliverble               0
# Highrolling_mean_3        0
# Highrolling_mean_7        0
# Lowrolling_mean_3         0
# Lowrolling_mean_7         0
# Lastrolling_mean_3        0
# Lastrolling_mean_7        0
# Turnoverrolling_mean_3    0
# Turnoverrolling_mean_7    0
# Tradesrolling_mean_3      0
# Tradesrolling_mean_7      0
# Highrolling_std_3         0
# Highrolling_std_7         0
# Lowrolling_std_3          0
# Lowrolling_std_7          0
# Lastrolling_std_3         0
# Lastrolling_std_7         0
# Turnoverrolling_std_3     0
# Turnoverrolling_std_7     0
# Tradesrolling_std_3       0
# Tradesrolling_std_7       0
# dtype: int64

# %%
data_2.columns
# Out:
# Index(['Symbol', 'Series', 'Prev Close', 'Open', 'High', 'Low', 'Last',
#        'Close', 'VWAP', 'Volume', 'Turnover', 'Trades', 'Deliverable Volume',
#        '%Deliverble', 'Highrolling_mean_3', 'Highrolling_mean_7',
#        'Lowrolling_mean_3', 'Lowrolling_mean_7', 'Lastrolling_mean_3',
#        'Lastrolling_mean_7', 'Turnoverrolling_mean_3',
#        'Turnoverrolling_mean_7', 'Tradesrolling_mean_3',
#        'Tradesrolling_mean_7', 'Highrolling_std_3', 'Highrolling_std_7',
#        'Lowrolling_std_3', 'Lowrolling_std_7', 'Lastrolling_std_3',
#        'Lastrolling_std_7', 'Turnoverrolling_std_3', 'Turnoverrolling_std_7',
#        'Tradesrolling_std_3', 'Tradesrolling_std_7'],
#       dtype='object')

# %%
ind_features=['Highrolling_mean_3', 'Highrolling_mean_7',
       'Lowrolling_mean_3', 'Lowrolling_mean_7', 'Lastrolling_mean_3',
       'Lastrolling_mean_7', 'Turnoverrolling_mean_3',
       'Turnoverrolling_mean_7', 'Tradesrolling_mean_3',
       'Tradesrolling_mean_7', 'Highrolling_std_3', 'Highrolling_std_7',
       'Lowrolling_std_3', 'Lowrolling_std_7', 'Lastrolling_std_3',
       'Lastrolling_std_7', 'Turnoverrolling_std_3', 'Turnoverrolling_std_7',
       'Tradesrolling_std_3', 'Tradesrolling_std_7']

# %%
#now  i divide the data into two sets.training data and test_data

training_data=data_2[0:1800]
test_data=data_2[1800:]

# %%
training_data
# Out:
#                 Symbol Series  Prev Close     Open     High      Low     Last  \
# Date
# 2011-06-09  BAJFINANCE     EQ      635.60   639.80   647.00   630.00   630.00
# 2011-06-10  BAJFINANCE     EQ      631.10   641.85   648.25   618.55   621.10
# 2011-06-13  BAJFINANCE     EQ      622.20   616.00   627.85   616.00   622.75
# 2011-06-14  BAJFINANCE     EQ      624.95   625.00   628.95   619.95   621.20
# 2011-06-15  BAJFINANCE     EQ      622.10   612.00   623.00   598.10   605.00
# ...                ...    ...         ...      ...      ...      ...      ...
# 2018-09-04  BAJFINANCE     EQ     2724.05  2724.00  2777.65  2683.50  2748.00
# 2018-09-05  BAJFINANCE     EQ     2746.30  2740.15  2764.80  2668.00  2704.45
# 2018-09-06  BAJFINANCE     EQ     2716.90  2729.00  2731.50  2671.40  2672.20
# 2018-09-07  BAJFINANCE     EQ     2684.10  2698.40  2751.40  2672.60  2745.00
# 2018-09-10  BAJFINANCE     EQ     2744.20  2732.00  2738.00  2596.00  2607.60
#
#               Close     VWAP   Volume  ...  Highrolling_std_3  \
# Date                                   ...
# 2011-06-09   631.10   638.27    31252  ...          12.769789
# 2011-06-10   622.20   634.16    30885  ...           1.639360
# 2011-06-13   624.95   622.92     3981  ...          11.434196
# 2011-06-14   622.10   625.35     5597  ...          11.473593
# 2011-06-15   601.70   606.90    12590  ...           3.165833
# ...             ...      ...      ...  ...                ...
# 2018-09-04  2746.30  2726.23  2606992  ...          88.954937
# 2018-09-05  2716.90  2712.53  1728455  ...          63.129081
# 2018-09-06  2684.10  2695.89  1147879  ...          23.818183
# 2018-09-07  2744.20  2716.32  1264436  ...          16.755397
# 2018-09-10  2615.65  2655.39  1570179  ...          10.147413
#
#             Highrolling_std_7  Lowrolling_std_3  Lowrolling_std_7  \
# Date
# 2011-06-09           7.494911         15.011107          9.410145
# 2011-06-10           8.227994         13.030765          9.501961
# 2011-06-13           9.497080          7.456597          9.298317
# 2011-06-14          10.198891          2.002707          9.293713
# 2011-06-15          11.352292         11.643560         11.262712
# ...                       ...               ...               ...
# 2018-09-04          79.489416         83.341306        107.041856
# 2018-09-05         100.594924         24.113551        119.854378
# 2018-09-06         113.135709          8.146779        118.187686
# 2018-09-07         106.101111          2.386071        100.988340
# 2018-09-10          84.670766         43.882722         74.650851
#
#             Lastrolling_std_3  Lastrolling_std_7  Turnoverrolling_std_3  \
# Date
# 2011-06-09           6.961741           8.089551           8.665128e+11
# 2011-06-10           6.290138           8.213628           1.579562e+11
# 2011-06-13           4.734536           7.106922           9.982094e+11
# 2011-06-14           0.925113           7.141512           9.595224e+11
# 2011-06-15           9.831116           8.999014           2.733211e+11
# ...                       ...                ...                    ...
# 2018-09-04          71.776528         105.853747           1.827289e+14
# 2018-09-05          22.060277         116.276260           1.375623e+14
# 2018-09-06          38.040121         122.556401           2.020435e+14
# 2018-09-07          36.478772          91.088720           8.394860e+13
# 2018-09-10          68.740769          76.419841           5.493903e+13
#
#             Turnoverrolling_std_7  Tradesrolling_std_3  Tradesrolling_std_7
# Date
# 2011-06-09           1.155773e+12           354.841279           463.942320
# 2011-06-10           1.136003e+12           272.875429           448.020620
# 2011-06-13           1.123423e+12           557.373603           464.778596
# 2011-06-14           8.397765e+11           656.385050           455.234163
# 2011-06-15           7.983186e+11           150.639747           436.941971
# ...                           ...                  ...                  ...
# 2018-09-04           1.673270e+14          2794.744413         21708.856675
# 2018-09-05           1.467744e+14         21770.352164         17267.163548
# 2018-09-06           1.561692e+14         30923.312263         24013.596897
# 2018-09-07           1.641199e+14         12123.301421         25604.694191
# 2018-09-10           1.647685e+14         15501.359822         25567.783116
#
# [1800 rows x 34 columns]

# %%
#to impplement arima on the data install the pmdarima library
# !pip install pmdarima
# !pip install statsmodels
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pmdarima in c:\users\reyuvel k kunjumon.jesus\appdata\roaming\python\python312\site-packages (2.0.4)
# Requirement already satisfied: joblib>=0.11 in c:\users\reyuvel k kunjumon.jesus\appdata\roaming\python\python312\site-packages (from pmdarima) (1.4.2)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\reyuvel k kunjumon.jesus\appdata\roaming\python\python312\site-packages (from pmdarima) (3.0.10)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\reyuvel k kunjumon.jesus\appdata\roaming\python\python312\site-packages (from pmdarima) (1.26.4)
# Requirement already satisfied: pandas>=0.19 in c:\users\reyuvel k kunjumon.jesus\appdata\roaming\python\python312\site-packages (from pmdarima) (2.2.2)
# Requirement already satisfied: scikit-learn>=0.22 in c:\users\reyuvel k kunjumon.jesus\appdata\roaming\python\python312\site-packages (from pmdarima) (1.4.2)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\reyuvel k kunjumon.jesus\appdata\roaming\python\python312\site-packages (from pmdarima) (1.13.0)
# Requirement already satisfied: statsmodels>=0.13.2 in c:\users\reyuvel k kunjumon.jesus\appdata\roaming\python\python312\site-packages (from pmdarima) (0.14.2)
# Requirement already satisfied: urllib3 in c:\users\reyuvel k kunjumon.jesus\appdata\roaming\python\python312\site-packages (from pmdarima) (1.26.18)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\reyuvel k kunjumon.jesus\appdata\roaming\python\python312\site-packages (from pmdarima) (70.1.1)
# Requirement already satisfied: packaging>=17.1 in c:\users\reyuvel k kunjumon.jesus\appdata\roaming\python\python312\site-packages (from pmdarima) (24.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\reyuvel k kunjumon.jesus\appdata\roaming\python\python312\site-packages (from pandas>=0.19->pmdarima) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\reyuvel k kunjumon.jesus\appdata\roaming\python\python312\site-packages (from pandas>=0.19->pmdarima) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\reyuvel k kunjumon.jesus\appdata\roaming\python\python312\site-packages (from pandas>=0.19->pmdarima) (2024.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\reyuvel k kunjumon.jesus\appdata\roaming\python\python312\site-packages (from scikit-learn>=0.22->pmdarima) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\reyuvel k kunjumon.jesus\appdata\roaming\python\python312\site-packages (from statsmodels>=0.13.2->pmdarima) (0.5.6)
# Requirement already satisfied: six in c:\users\reyuvel k kunjumon.jesus\appdata\roaming\python\python312\site-packages (from patsy>=0.5.6->statsmodels>=0.13.2->pmdarima) (1.16.0)
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: statsmodels in c:\users\reyuvel k kunjumon.jesus\appdata\roaming\python\python312\site-packages (0.14.2)
# Requirement already satisfied: numpy>=1.22.3 in c:\users\reyuvel k kunjumon.jesus\appdata\roaming\python\python312\site-packages (from statsmodels) (1.26.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\reyuvel k kunjumon.jesus\appdata\roaming\python\python312\site-packages (from statsmodels) (1.13.0)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\reyuvel k kunjumon.jesus\appdata\roaming\python\python312\site-packages (from statsmodels) (2.2.2)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\reyuvel k kunjumon.jesus\appdata\roaming\python\python312\site-packages (from statsmodels) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in c:\users\reyuvel k kunjumon.jesus\appdata\roaming\python\python312\site-packages (from statsmodels) (24.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\reyuvel k kunjumon.jesus\appdata\roaming\python\python312\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\reyuvel k kunjumon.jesus\appdata\roaming\python\python312\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\reyuvel k kunjumon.jesus\appdata\roaming\python\python312\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: six in c:\users\reyuvel k kunjumon.jesus\appdata\roaming\python\python312\site-packages (from patsy>=0.5.6->statsmodels) (1.16.0)
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from statsmodels.tsa.arima.model import ARIMA

model = ARIMA(training_data['VWAP'], order=(2, 0, 2), exog=training_data[ind_features])
model_fit = model.fit()  # No need for disp argument
# Out:
# C:\Users\Reyuvel K Kunjumon.JESUS\AppData\Roaming\Python\Python312\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Reyuvel K Kunjumon.JESUS\AppData\Roaming\Python\Python312\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Reyuvel K Kunjumon.JESUS\AppData\Roaming\Python\Python312\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Reyuvel K Kunjumon.JESUS\AppData\Roaming\Python\Python312\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\Reyuvel K Kunjumon.JESUS\AppData\Roaming\Python\Python312\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\Reyuvel K Kunjumon.JESUS\AppData\Roaming\Python\Python312\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
model_fit = model.fit()
# Out:
# C:\Users\Reyuvel K Kunjumon.JESUS\AppData\Roaming\Python\Python312\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\Reyuvel K Kunjumon.JESUS\AppData\Roaming\Python\Python312\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\Reyuvel K Kunjumon.JESUS\AppData\Roaming\Python\Python312\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
forecasted_values = model_fit.forecast(steps=len(test_data), exog=test_data[ind_features])
# Out:
# C:\Users\Reyuvel K Kunjumon.JESUS\AppData\Roaming\Python\Python312\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\Reyuvel K Kunjumon.JESUS\AppData\Roaming\Python\Python312\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(

# %%
test_data['Forecast_ARIMA']=forecasted_values.values
# Out:
# C:\Users\Reyuvel K Kunjumon.JESUS\AppData\Local\Temp\ipykernel_18264\3197935077.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['Forecast_ARIMA']=forecasted_values.values

# %%
# Print the first 5 elements of the forecast
test_data[['VWAP' , 'Forecast_ARIMA']].plot(figsize=(14,7))
# Out:
# <Axes: xlabel='Date'>

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
print(np.sqrt(mean_squared_error(test_data['VWAP'],test_data['Forecast_ARIMA'])))
 
print(mean_absolute_error(test_data['VWAP'],test_data['Forecast_ARIMA']))
# Out:
# 898.7956980056158
# 711.6934845360825

# %%
import matplotlib.pyplot as plt

# Plotting the actual VWAP values
plt.figure(figsize=(14,7))
plt.plot(test_data.index, test_data['VWAP'], label='Actual VWAP')

# Plotting the forecasted values
plt.plot(test_data.index, test_data['Forecast_ARIMA'], label='Forecast ARIMA', color='orange')

# Adding labels and legend
plt.xlabel('Date')
plt.ylabel('VWAP')
plt.title('Actual vs Forecasted VWAP')
plt.legend()

# Display the plot
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[196], line 1
# ----> 1 Forecast_AREMA
#
# NameError: name 'Forecast_AREMA' is not defined

# %%
import sys
print(sys.version)
# Out:
# 3.12.2 (tags/v3.12.2:6abddd9, Feb  6 2024, 21:26:36) [MSC v.1937 64 bit (AMD64)]

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(14,7))
test_data[['VWAP' , 'Forecast_ARIMA']].plot(ax=ax)  # Use the created axes object
plt.show()

# %%
import pmdarima

# %%
print(pmdarima.__version__)
# Out:
# 2.0.4
